# %% [markdown]
# # Altair Exercises

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from vega_datasets import data # pip install vega_datasets
import altair as alt  # pip install altair

# %%
plt.style.use("bmh")
plt.rcParams["figure.figsize"] = 16, 5

# %% [markdown]
# ## Exercise 1
#
# Plot the following dataset using points and color each variable differently.

# %%
size = 1000

np.random.seed(20210929)

dataset = pd.DataFrame({
    't': np.arange(size),
    'x': np.random.normal(1, 0.5, size=size).cumsum(),
    'y': np.random.normal(1, 0.5, size=size).cumsum(),
})

# %%
dataset
# Out:
#        t            x           y
# 0      0    -0.036793    1.083464
# 1      1     0.744165    1.052842
# 2      2     1.759292    2.222700
# 3      3     2.692845    2.532232
# 4      4     3.130959    3.310764
# ..   ...          ...         ...
# 995  995  1021.015534  983.326905
# 996  996  1022.007026  984.641751
# 997  997  1022.968159  985.206451
# 998  998  1023.887017  987.027823
# 999  999  1025.744296  988.567791
#
# [1000 rows x 3 columns]

# %%
alt.Chart(dataset).mark_point().encode(
    x='x',
    y='y',
    color="t"
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Exercise 2
#
# Add a moving avarage to the previous graph with a windows size of 20, without including future observations

# %%
alt.Chart(dataset).mark_point().encode(
    x='y',
    y='x',
    color="t"
).transform_window(
    moving_average='mean(x)',
    frame=[-20, 0],
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Exercise 3
#
# Using the previous data, create a new plot with a computed variable ($z$) equal to
#
# $$z = 2 x + \frac{1}{4} y$$
#
# Moreover, add the original graph with low opacity to compare.

# %% [markdown]
# ## Exercise 4
#
# Use some imputation rule to fill the gaps in the dataset and plot it with the original data in the background with low opacity

# %%
size = 1000

np.random.seed(20210929)

dataset = pd.DataFrame({
    't': np.arange(size),
    'x': np.random.normal(1, 0.5, size=size).cumsum(),
    'y': np.random.normal(1, 0.5, size=size).cumsum(),
})

x_index, y_index = np.random.random(size=(2, len(dataset))) < 0.1

dataset.loc[x_index, "x"] = np.nan
dataset.loc[y_index, "y"] = np.nan

dataset.head()
# Out:
#    t         x         y
# 0  0       NaN  0.780775
# 1  1  1.912114  1.298996
# 2  2       NaN  2.512684
# 3  3  4.298211       NaN
# 4  4       NaN       NaN

# %% [markdown]
# ## Exercise 5
#
# Replicate the following plot using Altair

# %%
penguins = sns.load_dataset("penguins")

sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# ## Exercise 6
#
# Re-do the previous plot with an interactive selection rectangle

# %% [markdown]
# ## Exercise 7
#
# Replicate the following plot using Altair

# %%
dataset = data.iris()

sns.pairplot(dataset, hue="species")

# %% [markdown]
# ## Exercise 8
#
# Re-do the previous plot with an interactive selection rectangle that propagates over all plots
